# %% [markdown]
# ****Data Cleaning EV sales data****

# %%
# importing neccessry libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action = "ignore")

# %%
# loading the dataset
data_his = pd.read_csv("data/historical_data.csv")
data_pro = pd.read_csv("data/data_project-APS.csv")

# %%
# check data description
data_his.info()
data_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3798 entries, 0 to 3797
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      3798 non-null   object
#  1   category    3798 non-null   object
#  2   parameter   3798 non-null   object
#  3   mode        3798 non-null   object
#  4   powertrain  3798 non-null   object
#  5   year        3798 non-null   int64
#  6   unit        3798 non-null   object
#  7   value       3798 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 237.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      457 non-null    object
#  1   category    457 non-null    object
#  2   parameter   457 non-null    object
#  3   mode        457 non-null    object
#  4   powertrain  457 non-null    object
# ...

# %%
# check first 10 rows 
data_his.head(10)
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
# 5  Australia  Historical        EV stock  Cars       PHEV  2012  Vehicles
# 6  Australia  Historical        EV sales  Cars       PHEV  2012  Vehicles
# 7  Australia  Historical  EV sales share  Cars         EV  2012   percent
# 8  Australia  Historical  EV stock share  Cars         EV  2012   percent
# 9  Australia  Historical        EV sales  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000
# 5   80.00000
# 6   80.00000
# 7    0.03000
# 8    0.00240
# ...

# %%
#check for duplicates
print(data_his.duplicated().sum())
print(data_pro.duplicated().sum())
# Out:
# 0
# 0

# %%
# Get unique powertrain types
unique_powertrains = data_his['powertrain'].unique()
print(unique_powertrains)
# Out:
# ['BEV' 'EV' 'PHEV' 'FCEV']

# %%
# Filter rows where powertrain is NOT 'FCEV' and historical ev sales data 
filtered_data = data_his[(data_his['powertrain'] != 'FCEV') & (data_his['parameter'] == 'EV sales')]
filtered_data.head()
# Out:
#        region    category parameter  mode powertrain  year      unit  value
# 0   Australia  Historical  EV sales  Cars        BEV  2011  Vehicles   49.0
# 6   Australia  Historical  EV sales  Cars       PHEV  2012  Vehicles   80.0
# 9   Australia  Historical  EV sales  Cars        BEV  2012  Vehicles  170.0
# 10  Australia  Historical  EV sales  Cars        BEV  2013  Vehicles  190.0
# 13  Australia  Historical  EV sales  Cars       PHEV  2013  Vehicles  100.0

# %%
# Create a ev_sales historical table with selected columns and rename 'value' to 'sales'
df_ev_sales_his = filtered_data[['region', 'year', 'powertrain', 'value']].rename(columns={'value': 'sales'}).reset_index(drop=True)
df_ev_sales_his.head()
# Out:
#       region  year powertrain  sales
# 0  Australia  2011        BEV   49.0
# 1  Australia  2012       PHEV   80.0
# 2  Australia  2012        BEV  170.0
# 3  Australia  2013        BEV  190.0
# 4  Australia  2013       PHEV  100.0

# %%
# Filter rows where powertrain is NOT 'FCEV' and project ev sales data and year greater than 2024
filtered_data_pro = data_pro[(data_pro['powertrain'] != 'FCEV') &
                             (data_pro['parameter'] == 'EV sales') & 
                             (data_pro['year']>2024)].reset_index(drop=True)
filtered_data_pro.head()
# Out:
#   region        category parameter  mode powertrain  year      unit  \
# 0  China  Projection-APS  EV sales  Cars        BEV  2025  Vehicles
# 1  China  Projection-APS  EV sales  Cars       PHEV  2025  Vehicles
# 2  China  Projection-APS  EV sales  Cars        BEV  2030  Vehicles
# 3  China  Projection-APS  EV sales  Cars       PHEV  2030  Vehicles
# 4  China  Projection-APS  EV sales  Cars        BEV  2035  Vehicles
#
#         value
# 0   8300000.0
# 1   2600000.0
# 2  15000000.0
# 3   2500000.0
# 4  20000000.0

# %%
# Create a ev_sales projection table with selected columns and rename 'value' to 'sales'
df_ev_sales_pro = filtered_data_pro[['region', 'year', 'powertrain', 'value']].rename(columns={'value': 'sales'})
df_ev_sales_pro.head()
# Out:
#   region  year powertrain       sales
# 0  China  2025        BEV   8300000.0
# 1  China  2025       PHEV   2600000.0
# 2  China  2030        BEV  15000000.0
# 3  China  2030       PHEV   2500000.0
# 4  China  2035        BEV  20000000.0

# %% [markdown]
# ****Data Cleaning EV charging points data****

# %%
# loading the dataset
chargingp_his = pd.read_csv("data/charging points_his.csv")
chargingp_pro = pd.read_csv("data/charging points_pro.csv")

# %%
# check data description
chargingp_his.info()
chargingp_pro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      750 non-null    object
#  1   category    750 non-null    object
#  2   parameter   750 non-null    object
#  3   mode        750 non-null    object
#  4   powertrain  750 non-null    object
#  5   year        750 non-null    int64
#  6   unit        750 non-null    object
#  7   value       750 non-null    float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 47.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      84 non-null     object
#  1   category    84 non-null     object
#  2   parameter   84 non-null     object
#  3   mode        84 non-null     object
#  4   powertrain  84 non-null     object
# ...

# %%
#check for duplicates
print(chargingp_his.duplicated().sum())
print(chargingp_pro.duplicated().sum())
# Out:
# 0
# 0

# %%
# read the frist 10 rows
chargingp_his.head(10)
# Out:
#       region    category           parameter mode               powertrain  \
# 0  Australia  Historical  EV charging points   EV  Publicly available fast
# 1  Australia  Historical  EV charging points   EV  Publicly available slow
# 2  Australia  Historical  EV charging points   EV  Publicly available fast
# 3  Australia  Historical  EV charging points   EV  Publicly available slow
# 4  Australia  Historical  EV charging points   EV  Publicly available slow
# 5  Australia  Historical  EV charging points   EV  Publicly available slow
# 6  Australia  Historical  EV charging points   EV  Publicly available fast
# 7  Australia  Historical  EV charging points   EV  Publicly available slow
# 8  Australia  Historical  EV charging points   EV  Publicly available fast
# 9  Australia  Historical  EV charging points   EV  Publicly available slow
#
#    year             unit   value
# 0  2017  charging points    40.0
# 1  2017  charging points   440.0
# 2  2018  charging points    61.0
# ...

# %%
# group by region and year, then sum the values for all types (fast and slow)
df_chargingp_his =chargingp_his.groupby(['region', 'year']).agg({'value': 'sum'}).reset_index()
df_chargingp_his.head()
# Out:
#       region  year   value
# 0  Australia  2017   480.0
# 1  Australia  2018   731.0
# 2  Australia  2019  1700.0
# 3  Australia  2020  2300.0
# 4  Australia  2021  2320.0

# %%
# read the frist 10 rows
chargingp_pro.head(10)
# Out:
#   region        category           parameter mode               powertrain  \
# 0  China  Projection-APS  EV charging points   EV  Publicly available fast
# 1  China  Projection-APS  EV charging points   EV  Publicly available slow
# 2  China  Projection-APS  EV charging points   EV  Publicly available fast
# 3  China  Projection-APS  EV charging points   EV  Publicly available slow
# 4  China  Projection-APS  EV charging points   EV  Publicly available fast
# 5  China  Projection-APS  EV charging points   EV  Publicly available slow
# 6  China  Projection-APS  EV charging points   EV  Publicly available fast
# 7  China  Projection-APS  EV charging points   EV  Publicly available slow
# 8  China  Projection-APS  EV charging points   EV  Publicly available fast
# 9  China  Projection-APS  EV charging points   EV  Publicly available slow
#
#    year             unit    value
# 0  2020  charging points   310000
# 1  2020  charging points   500000
# 2  2021  charging points   470000
# ...

# %%
# filter data with year great than 2024
df_filtered = chargingp_pro[chargingp_pro['year']>2024]
# group by region and year, then sum the values for all types (fast and slow)
df_chargingp_pro=df_filtered.groupby(['region', 'year']).agg({'value': 'sum'}).reset_index()
df_chargingp_pro.head()
# Out:
#    region  year     value
# 0   China  2025   4700000
# 1   China  2030  10800000
# 2   China  2035  15500000
# 3  Europe  2025   1060000
# 4  Europe  2030   1750000

# %% [markdown]
# ****Save the cleaned datasets****

# %%
#Save the result to a CSV file
df_ev_sales_his.to_csv('cleaned data/ev_sales_his.csv', index=False)
df_ev_sales_pro.to_csv('cleaned data/ev_sales_pro.csv', index=False)
df_chargingp_his.to_csv('cleaned data/ev_chargingpoint_his.csv', index=False)
df_chargingp_pro.to_csv('cleaned data/ev_chargingpoint_pro.csv', index=False)
